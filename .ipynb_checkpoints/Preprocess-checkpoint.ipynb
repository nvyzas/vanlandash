# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./data/data.csv')

# %%
df
# Out:
#          Unnamed: 0   a_key    b_key  ...  is_blacklist is_redlist  is_whitelist
# 0                42   A5418  B226746  ...         False      False          True
# 1                16  A16062  B226746  ...         False      False          True
# 2                15   A5095  B226746  ...         False      False          True
# 3                11  A29672  B226746  ...         False      False          True
# 4                19  A22891  B226746  ...         False      False          True
# ...             ...     ...      ...  ...           ...        ...           ...
# 5651581     5317241   A4999  B217879  ...         False      False         False
# 5651582     5317242   A7639  B217879  ...         False      False         False
# 5651583     5317244  A35875  B217879  ...         False      False         False
# 5651584     5317222   A4049  B217879  ...         False      False         False
# 5651585     5350540  A44330  B240156  ...         False      False         False
#
# [5651586 rows x 8 columns]

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0    a_key    b_key  ...  is_blacklist is_redlist is_whitelist
# count   5.651586e+06  5651586  5651586  ...       5651586    5651586      5651586
# unique           NaN    63700   692576  ...             2          2            2
# top              NaN   A42290  B226746  ...         False      False        False
# freq             NaN    84771   212526  ...       5602010    5650785      5392483
# mean    2.674981e+06      NaN      NaN  ...           NaN        NaN          NaN
# std     1.552608e+06      NaN      NaN  ...           NaN        NaN          NaN
# min     0.000000e+00      NaN      NaN  ...           NaN        NaN          NaN
# 25%     1.325150e+06      NaN      NaN  ...           NaN        NaN          NaN
# 50%     2.672750e+06      NaN      NaN  ...           NaN        NaN          NaN
# 75%     4.019848e+06      NaN      NaN  ...           NaN        NaN          NaN
# max     5.651582e+06      NaN      NaN  ...           NaN        NaN          NaN
#
# [11 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5651586 entries, 0 to 5651585
# Data columns (total 8 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   a_key         object
#  2   b_key         object
#  3   boeking_eur   float64
#  4   date_tech     object
#  5   is_blacklist  bool
#  6   is_redlist    bool
#  7   is_whitelist  bool
# dtypes: bool(3), float64(1), int64(1), object(3)
# memory usage: 231.8+ MB

# %%
df['date_tech'] = df['date_tech'].astype('datetime64[ns]')
df['a_key']=df['a_key'].astype('string')
df['b_key']=df['a_key'].astype('string')
df.drop(columns=['Unnamed: 0'],inplace=True)
df
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-26-8f221284af62>", line 4, in <module>
#     df.drop(columns=['Unnamed: 0'],inplace=True)
#
#   File "/media/nick/Data/PDEng/Modules/Intro2DS/Fraud_Detection-Van_Lanschot/source/venv/lib/python3.7/site-packages/pandas/core/frame.py", line 3997, in drop
#     errors=errors,
#
#   File "/media/nick/Data/PDEng/Modules/Intro2DS/Fraud_Detection-Van_Lanschot/source/venv/lib/python3.7/site-packages/pandas/core/generic.py", line 3936, in drop
#     obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#
#   File "/media/nick/Data/PDEng/Modules/Intro2DS/Fraud_Detection-Van_Lanschot/source/venv/lib/python3.7/site-packages/pandas/core/generic.py", line 3970, in _drop_axis
#     new_axis = axis.drop(labels, errors=errors)
#
#   File "/media/nick/Data/PDEng/Modules/Intro2DS/Fraud_Detection-Van_Lanschot/source/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 5018, in drop
#     raise KeyError(f"{labels[mask]} not found in axis")
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.dtypes
# Out:
# b_key                   string
# boeking_eur            float64
# date_tech       datetime64[ns]
# is_blacklist              bool
# is_redlist                bool
# is_whitelist              bool
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['a_key'])
# Out:
# pandas.core.series.Series

# %%
type(df['a_key'].values)

# %%
type(df['a_key'][0])

# %%
df.to_pickle('./data/data_preprocessed.pkl')

# %%
df=pd.read_pickle('./data/data_preprocessed.pkl')
display(df,df.dtypes)
# Out:
#           a_key   b_key  boeking_eur  ... is_blacklist  is_redlist  is_whitelist
# 0         A5418   A5418     -9286.00  ...        False       False          True
# 1        A16062  A16062     -3404.00  ...        False       False          True
# 2         A5095   A5095     -3000.00  ...        False       False          True
# 3        A29672  A29672     -1642.00  ...        False       False          True
# 4        A22891  A22891     -3048.00  ...        False       False          True
# ...         ...     ...          ...  ...          ...         ...           ...
# 5651581   A4999   A4999       -68.54  ...        False       False         False
# 5651582   A7639   A7639      -697.59  ...        False       False         False
# 5651583  A35875  A35875      -423.98  ...        False       False         False
# 5651584   A4049   A4049       -63.39  ...        False       False         False
# 5651585  A44330  A44330       -22.00  ...        False       False         False
#
# [5651586 rows x 7 columns]
# a_key                   string
# b_key                   string
# boeking_eur            float64
# date_tech       datetime64[ns]
# is_blacklist              bool
# is_redlist                bool
# is_whitelist              bool
# dtype: object
